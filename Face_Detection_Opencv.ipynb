# %%
# !unzip -q "/content/iloveimg-resized.zip" -d "/content/new"

# %%
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.vgg16 import preprocess_input,decode_predictions
import numpy as np

# %%
#remove a folder
# !rm -rf "/content/rajini/"

# %%
#remove a folder
# !rm -rf "/content/rajini_fd_1"

# %%
ii=[]

# %%
# import required module
from pathlib import Path
 
# get the path/directory
folder_dir = '/content/new'
# iterate over files in
# that directory
images = Path(folder_dir).glob('*')
for image in images:
    print(image)
    ii.append(str(image))
# Out:
# /content/new/image.jpeg
# /content/new/image3.jpeg
# /content/new/image6.jpeg
# /content/new/image10.jpeg
# /content/new/image9.jpeg
# /content/new/image5.jpeg
# /content/new/image4.jpeg
# /content/new/image7.jpeg
# /content/new/image2.jpeg
# /content/new/image8.jpeg

# %%
len(ii)
# Out:
# 10

# %%
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.vgg16 import preprocess_input,decode_predictions
import numpy as np

# %%
img_path = ii[1]
img = image.load_img(img_path,color_mode='rgb')
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=256x256 at 0x7FCC3CF02950>

# %%
len(ii)
# Out:
# 10

# %%
nums = range(0,len(ii))
num1=(list(map(str, nums)))
aa=[]
for i in range(0,len(num1)):
  ww="/content/kamal256/"+num1[i]+".jpeg"
  aa.append(ww)

# %%
aa
# Out:
# ['/content/kamal256/0.jpeg',
#  '/content/kamal256/1.jpeg',
#  '/content/kamal256/2.jpeg',
#  '/content/kamal256/3.jpeg',
#  '/content/kamal256/4.jpeg',
#  '/content/kamal256/5.jpeg',
#  '/content/kamal256/6.jpeg',
#  '/content/kamal256/7.jpeg',
#  '/content/kamal256/8.jpeg',
#  '/content/kamal256/9.jpeg']

# %% [markdown]
# detecting the face and reshaped the image and exporting

# %%
import cv2
import dlib
from google.colab.patches import cv2_imshow
# Load the detector
detector = dlib.get_frontal_face_detector()
# read the image
for i in range(0,len(ii)):
  img = cv2.imread(ii[i])
  # Convert image into grayscale
  gray = cv2.cvtColor(src=img, code=cv2.COLOR_BGR2GRAY)
  # Use detector to find landmarks
  faces = detector(gray)
  for face in faces:
      x1 = face.left() # left point
      y1 = face.top() # top point
      x2 = face.right() # right point
      y2 = face.bottom() # bottom point
      # Draw a rectangle
      cv2.rectangle(img=img, pt1=(x1, y1), pt2=(x2, y2), color=(0, 255, 0), thickness=1)
      if y1 > 0:
        cropped = img [y1:y2, x1:x2]
        yy=cv2.resize(cropped, (224, 224)) 
        cv2.imwrite(aa[i], yy)
      else:
        break

  # show the image
  cv2_imshow(img)
  # Wait for a key press to exit
  cv2.waitKey(delay=0)
  # Close all windows
  cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FCBC8FE3310>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FCBC8FE3290>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FCBC8FE3990>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FCBC8FE3990>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FCBC8FE3290>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FCBC8FF46D0>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FCBC8FE3310>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FCBC8FE3310>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FCBC8FE3310>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FCBC8FE34D0>

# %%
from matplotlib import pyplot as plt
plt.imshow(cropped)

# %% [markdown]
# exporting the processed images to local

# %%
import shutil

# %%
file_to = '/content/final/kamal2222'
file_format = 'zip'
file_from = '/content/rajini'
shutil.make_archive(file_to, file_format, file_from)
# Out:
# '/content/final/rajini22.zip'
